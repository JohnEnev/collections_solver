# %% [markdown]
# # 02 - Generate Traces
#
# This notebook generates reasoning traces from base models solving Connections puzzles.

# %%
import json
from pathlib import Path
import sys

sys.path.insert(0, str(Path.cwd().parent / 'src'))

from game_loop import play_game_with_trace
from utils import load_jsonl

# %% [markdown]
# ## Generate Traces with Base Model
#
# Run the game loop and collect reasoning traces.

# %%
# Example trace generation
# results = []
# for puzzle in puzzles:
#     trace = play_game_with_trace(puzzle, model="gpt-4o-mini")
#     results.append(trace)
